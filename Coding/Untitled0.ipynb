# %%
import spacy
nlp = spacy.load('en_core_web_sm')
s = "This is a string of text, Mr. J. Simpson said. Astounding."
doc = nlp(s)

for word in doc:
    print (word)

for word in doc.sents:
    print(word)
# Out:
# This
# is
# a
# string
# of
# text
# ,
# Mr.
# J.
# Simpson
# said
# .
# Astounding
# .
# This is a string of text, Mr. J. Simpson said.
# Astounding.
